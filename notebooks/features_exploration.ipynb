# %% [markdown]
# - The purpose of this notebook is to explore the features in the cleaned dataset, engineer new features based on the target variable (SalePrice), optimize existing ones, and evaluate the results using the Random Forest Regressor model.

# %%
import pandas as pd

# %%
df = pd.read_csv('../cleaned_data/cleaned_housing_data.csv')

# %%
df.head(5)
# Out:
#          Id  MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# 0 -1.000000         0.2        -0.25 -0.254076          0.5          0.0
# 1 -0.998629        -0.6         0.50  0.030015          0.0          3.0
# 2 -0.997258         0.2        -0.10  0.437624          0.5          0.0
# 3 -0.995888         0.4        -0.50  0.017663          0.5          0.0
# 4 -0.994517         0.2         0.70  1.181201          1.0          0.0
#
#    YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  \
# 0   0.652174      0.243243    1.193303    0.452790  ...    0.000000
# 1   0.065217     -0.486486    0.000000    0.834679  ...    1.773810
# 2   0.608696      0.216216    0.986301    0.143910  ...    0.000000
# 3  -1.260870     -0.648649    0.000000   -0.235170  ...    0.000000
# 4   0.586957      0.162162    2.130898    0.381186  ...    1.142857
#
#    OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# ...
